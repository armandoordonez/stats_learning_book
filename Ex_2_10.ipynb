# %% [markdown]
# <a href="https://colab.research.google.com/github/armandoordonez/stats_learning_book/blob/main/Ex_2_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# https://botlnec.github.io/islp/sols/chapter2/exercise10/

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston

#boston = pd.read_csv("https://raw.githubusercontent.com/armandoordonez/stats_learning_book/main/boston.csv")

column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
boston = pd.read_csv('https://raw.githubusercontent.com/armandoordonez/stats_learning_book/main/boston.csv', header = None, delimiter = r"\s+", names = column_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
np.shape(df)
# Out:
# (506, 14)

# %%
g = sns.PairGrid(df)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(plt.scatter, s=3)
g.fig.set_size_inches(12, 12)

# %%
plt.scatter(df['RM'], df['target'])
plt.xlabel('RM')
plt.ylabel('target');

# %%
plt.scatter(df['LSTAT'], df['target'])
plt.xlabel('LSTAT')
plt.ylabel('target');

# %%
plt.scatter(df['RM'], df['LSTAT'])
plt.xlabel('RM')
plt.ylabel('LSTAT');

# %%
plt.scatter(df['TAX'], df['CRIM'])
plt.xlabel('TAX')
plt.ylabel('CRIM');

# %%
df.corrwith(df['CRIM']).sort_values()
# Out:
# target    -0.388305
# B         -0.385064
# DIS       -0.379670
# RM        -0.219247
# ZN        -0.200469
# CHAS      -0.055892
# PTRATIO    0.289946
# AGE        0.352734
# INDUS      0.406583
# NOX        0.420972
# LSTAT      0.455621
# TAX        0.582764
# RAD        0.625505
# CRIM       1.000000
# dtype: float64

# %%
ax = sns.boxplot(x="RAD", y="CRIM", data=df)

# %%
plt.scatter(df['TAX'], df['CRIM'])
plt.xlabel('TAX')
plt.ylabel('CRIM');

# %%
plt.scatter(df['LSTAT'], df['CRIM'])
plt.xlabel('LSTAT')
plt.ylabel('CRIM');

# %%
df.loc[df['CRIM'].nlargest(5).index]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 418  73.5341  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  51.1358  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 414  45.7461  0.0   18.1   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
#
#      PTRATIO       B  LSTAT  target
# 380     20.2  396.90  17.21    10.4
# 418     20.2   16.45  20.62     8.8
# 405     20.2  384.97  22.98     5.0
# 410     20.2    2.60  10.11    15.0
# 414     20.2   88.27  36.98     7.0

# %%
df.loc[df['TAX'].nlargest(5).index]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 488  0.15086  0.0  27.74   0.0  0.609  5.454  92.7  1.8209  4.0  711.0
# 489  0.18337  0.0  27.74   0.0  0.609  5.414  98.3  1.7554  4.0  711.0
# 490  0.20746  0.0  27.74   0.0  0.609  5.093  98.0  1.8226  4.0  711.0
# 491  0.10574  0.0  27.74   0.0  0.609  5.983  98.8  1.8681  4.0  711.0
# 492  0.11132  0.0  27.74   0.0  0.609  5.983  83.5  2.1099  4.0  711.0
#
#      PTRATIO       B  LSTAT  target
# 488     20.1  395.09  18.06    15.2
# 489     20.1  344.05  23.97     7.0
# 490     20.1  318.43  29.68     8.1
# 491     20.1  390.11  18.07    13.6
# 492     20.1  396.90  13.35    20.1

# %%
df.loc[df['PTRATIO'].nlargest(5).index]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD    TAX  \
# 354  0.04301  80.0   1.91   0.0  0.413  5.663  21.9  10.5857  4.0  334.0
# 355  0.10659  80.0   1.91   0.0  0.413  5.936  19.5  10.5857  4.0  334.0
# 127  0.25915   0.0  21.89   0.0  0.624  5.693  96.0   1.7883  4.0  437.0
# 128  0.32543   0.0  21.89   0.0  0.624  6.431  98.8   1.8125  4.0  437.0
# 129  0.88125   0.0  21.89   0.0  0.624  5.637  94.7   1.9799  4.0  437.0
#
#      PTRATIO       B  LSTAT  target
# 354     22.0  382.80   8.05    18.2
# 355     22.0  376.04   5.57    20.6
# 127     21.2  392.11  17.19    16.2
# 128     21.2  396.90  15.39    18.0
# 129     21.2  396.90  18.34    14.3

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['CHAS'].value_counts()[1]
# Out:
# 35

# %%
df['PTRATIO'].median()
# Out:
# 19.05

# %%
df['target'].idxmin()
# Out:
# 398

# %%
a = df.describe()
a.loc['range'] = a.loc['max'] - a.loc['min']
a
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
# range   88.969880  100.000000   27.280000    1.000000    0.486000    5.219000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %%
len(df[df['RM']>7])
# Out:
# 64

# %%
len(df[df['RM']>8])
# Out:
# 13

# %%
df[df['RM']>8].describe()
# Out:
#             CRIM         ZN      INDUS       CHAS        NOX         RM  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              AGE        DIS        RAD         TAX    PTRATIO           B  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...
